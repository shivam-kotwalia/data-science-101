# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
X = np.random.random(1024)
Y = np.random.random(1024)

# %%
plt.scatter(X,Y, s=20, alpha=0.5, marker='p')

# %%
plt.xlim(-1.5, 1.5)
plt.scatter(X,Y, s=20, alpha=0.5, marker='p')

# %%
plt.xlim(-1.5, 1.5)
plt.yticks()
plt.scatter(X,Y, s=20, alpha=0.5, marker='p')

# %%
X1 = ["a", 'b', 'c', 'd']
Y1 = [12, 13, 14, 15]
plt.bar(X1, Y1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(X1, Y1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.pie(Y1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e8a3d666a0>,
# ...
#  [Text(0.842649,0.707066,''),
#   Text(-0.60446,0.919037,''),
#   Text(-0.919037,-0.60446,''),
#   Text(0.707066,-0.842649,'')])

# %%
plt.pie(Y1, labels=X1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e8a3d80ef0>,
# ...
#  [Text(0.842649,0.707066,'a'),
#   Text(-0.60446,0.919037,'b'),
#   Text(-0.919037,-0.60446,'c'),
#   Text(0.707066,-0.842649,'d')])

# %%
plt.plot(X1, Y1)

# %%
import matplotlib as mp

# %%
my_font = {"size": 30,
          "weight": 'bold', 
          'family': 'normal'}

# %%
mp.rc('font', **my_font)

# %%
# Second Options
mp.rcParams.update({'font.size': 40})

# %%
plt.pie(Y1, labels=X1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e8a3ea6b00>,
# ...
#  [Text(0.842649,0.707066,'a'),
#   Text(-0.60446,0.919037,'b'),
#   Text(-0.919037,-0.60446,'c'),
#   Text(0.707066,-0.842649,'d')])
# C:\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Normalization

# %%
age_all = np.random.randint(25, 70, size=10)

# %%
age_all.max()
# Out:
# 69

# %%
age_all/age_all.max()
# Out:
# array([0.42028986, 0.69565217, 0.73913043, 0.49275362, 0.68115942,
#        0.43478261, 0.50724638, 0.37681159, 0.79710145, 1.        ])

# %%
[(x - age_all.min())/(age_all.max()-age_all.min()) for x in age_all]
# Out:
# [0.06976744186046512,
#  0.5116279069767442,
#  0.5813953488372093,
#  0.18604651162790697,
#  0.4883720930232558,
#  0.09302325581395349,
#  0.20930232558139536,
#  0.0,
#  0.6744186046511628,
#  1.0]

# %%
(age_all - age_all.min())/(age_all.max() - age_all.min())
# Out:
# array([0.06976744, 0.51162791, 0.58139535, 0.18604651, 0.48837209,
#        0.09302326, 0.20930233, 0.        , 0.6744186 , 1.        ])

# %%
ct = np.random.randint(25, 70, size=30)

# %%
ct.mean()
# Out:
# 46.93333333333333

# %%
Admin@123
